# %%
import pandas as pd

# %%
pd.read_excel('../dataset/sample_data.xlsx')
# Out:
#         Year  Stocks T.Bills T.Bonds
# 0       1928  0.4381  0.0308  0.0084
# 1       1929  -0.083  0.0316   0.042
# 2       1930 -0.2512  0.0455  0.0454
# 3       1931 -0.4384  0.0231 -0.0256
# 4       1932 -0.0864  0.0107  0.0879
# ..       ...     ...     ...     ...
# 78      2006  0.1579  0.0119  0.0298
# 79      2007  0.0549  0.0988  0.0466
# 80      2008   -0.37  0.2587   0.016
# 81      2009  0.2646  -0.149   0.001
# 82  averages  stocks  tbills   bonds
#
# [83 rows x 4 columns]

# %%
pd.read_excel('../dataset/sample_data.xlsx', index_col='Year')
# Out:
#           Stocks T.Bills T.Bonds
# Year
# 1928      0.4381  0.0308  0.0084
# 1929      -0.083  0.0316   0.042
# 1930     -0.2512  0.0455  0.0454
# 1931     -0.4384  0.0231 -0.0256
# 1932     -0.0864  0.0107  0.0879
# ...          ...     ...     ...
# 2006      0.1579  0.0119  0.0298
# 2007      0.0549  0.0988  0.0466
# 2008       -0.37  0.2587   0.016
# 2009      0.2646  -0.149   0.001
# averages  stocks  tbills   bonds
#
# [83 rows x 3 columns]

# %%
pd.read_excel('../dataset/sample_data.xlsx', sheet_name='Sheet1' )

# %% [markdown]
# ### loading txt file

# %%
pd.read_csv("../dataset/text.txt")
# Out:
#     employee_id                       name             department  \
# 0             1           Ahmad Bin Rahman                Finance
# 1             2  Nurul Aishah Binti Ismail                     HR
# 2             3     Mohd Arif Bin Abdullah                     IT
# 3             4  Siti Fatimah Binti Hassan              Marketing
# 4             5               Tan Wei Ming            Engineering
# 5             6               Rajesh Kumar                  Sales
# 6             7               Lee Mei Ling                Finance
# 7             8    Khairul Nizam Bin Yusof                     IT
# 8             9        Aminah Binti Zainal             Operations
# 9            10         David Lim Chee Wei            Engineering
# 10           11  Fatimah Zahra Binti Osman                     HR
# 11           12             Azlan Bin Mohd              Marketing
# 12           13                Ng Siew Mei                  Sales
# ...
