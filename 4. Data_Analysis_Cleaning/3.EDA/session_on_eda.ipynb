# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('train.csv')

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# ## Why do EDA
#
# ##### Model building:
# - sense of data is required in better way so that a better or good models can be created correpondingly with machine learning models or deeplearning or any others
#
# ##### Analysis and reporting:
# - not always model development is requiured. But sometimes there can be scenarios for analysis and reporting only like sales dataset and check the profit and loss statement.
#
# #####  Validate assumptions:
# - Test the assumptions and validate those assumptions like check which gender are prone to accidents.
#
# #####  Handling missing values
# - Check and handle the missing values, cannot fill randonmly
#
# ##### feature engineering
# - which features/columns are important, deriving which columns are required for the model development apporach.
#
# ##### detecting outliers
# - find those which are different from any other
#
# So, EDA is a must in the domain of DataScience or DataAnalysis and need to perform always and is very very important.
#
# Remember it is an iterative process. Deduce results and again and again perform the steps and draw conclusions. It is not a one go process at all.

# %% [markdown]
# ## **Step 1: Find and label the column types for each of the columns available in the dataset**
#
# ### Column Types
#
# - **Numerical** - Age,Fare,PassengerId
# - **Categorical** - Survived, Pclass, Sex, SibSp, Parch,Embarked
# - **Mixed** - Name, Ticket, Cabin

# %% [markdown]
# ## **Step 2: Univariate, Bivariate and Multivariate Analysis**
#
# ### Univariate Analysis : done 1st
# Univariate analysis focuses on analyzing each feature in the dataset independently. One column/feature at a time.
#
# ### Bivariate Analysis: 2nd
# Analysis on two columns at a single time.
#
# ### Multivariate Analysis
# Analysis on more than 2 columns or multiple at the same time.

# %% [markdown]
# ### Univariate Analysis :
# Univariate analysis focuses on analyzing each feature in the dataset independently. One column/feature at a time.
#
# - **Distribution analysis**: The distribution of each feature is examined to identify its shape, central tendency, and dispersion.
#
# - **Identifying potential issues**: Univariate analysis helps in identifying potential problems with the data such as outliers, skewness, and missing values
#
# #### The shape of a data distribution refers to its overall pattern or form as it is represented on a graph. Some common shapes of data distributions include:
#
# - **Normal Distribution**: A symmetrical and bell-shaped distribution where the mean, median, and mode are equal and the majority of the data falls in the middle of the distribution with gradually decreasing frequencies towards the tails.
#
# - **Skewed Distribution**: A distribution that is not symmetrical, with one tail being longer than the other. It can be either positively skewed (right-skewed) or negatively skewed (left-skewed).
#
# - **Bimodal Distribution**: A distribution with two peaks or modes.
#
# - **Uniform Distribution**: A distribution where all values have an equal chance of occurring.
#
# The shape of the data distribution is important in identifying the presence of outliers, skewness, and the type of statistical tests and models that can be used for further analysis.

# %% [markdown]
# #### **Dispersion** is a statistical term used to describe the spread or variability of a set of data. It measures how far the values in a data set are spread out from the central tendency (mean, median, or mode) of the data.
#
# There are several measures of dispersion, including:
#
# - **Range**: The difference between the largest and smallest values in a data set.
#
# - **Variance**: The average of the squared deviations of each value from the mean of the data set.
#
# - **Standard Deviation**: The square root of the variance. It provides a measure of the spread of the data that is in the same units as the original data.
#
# - **Interquartile range (IQR)**: The range between the first quartile (25th percentile) and the third quartile (75th percentile) of the data.
#
# Dispersion helps to describe the spread of the data, which can help to identify the presence of outliers and skewness in the data.

# %% [markdown]
# ### Steps of doing Univariate Analysis on Numerical columns
#
# - **Descriptive Statistics**: Compute basic summary statistics for the column, such as mean, median, mode, standard deviation, range, and quartiles. These statistics give a general understanding of the distribution of the data and can help identify skewness or outliers.
#
# - **Visualizations**: Create visualizations to explore the distribution of the data. Some common visualizations for numerical data include histograms, box plots, and density plots. These visualizations provide a visual representation of the distribution of the data and can help identify skewness an outliers.
#
# - **Identifying Outliers**: Identify and examine any outliers in the data. Outliers can be identified using visualizations. It is important to determine whether the outliers are due to measurement errors, data entry errors, or legitimate differences in the data, and to decide whether to include or exclude them from the analysis.
#
# - **Skewness**: Check for skewness in the data and consider transforming the data or using robust statistical methods that are less sensitive to skewness, if necessary.
#
# - **Conclusion**: Summarize the findings of the EDA and make decisions about how to proceed with further analysis.

# %% [markdown]
# ### Age: performing univariate analysis on age column
#
# Our goal is to build a predictive model, that can conclude on the given data whether the passenger would survive or not

# %%
df['Age'].describe()
# Out:
# count    714.000000
# mean      29.699118
# std       14.526497
# min        0.420000
# 25%       20.125000
# 50%       28.000000
# 75%       38.000000
# max       80.000000
# Name: Age, dtype: float64

# %%
df['Age'].plot(kind='hist',bins=20)
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# We can see that the passengers is neither lesser age group nor higher as there is lesser distribution bu the 20-40 age group is most

# %%
df['Age'].plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %% [markdown]
# not exactly normal but kind of normal and not too much skewed

# %%
df['Age'].skew()
# Out:
# np.float64(0.38910778230082704)

# %% [markdown]
# As we have the value nearly equal to 0 so it can be assumed as normal distribution. If the value of skew() is exactly 0 then it is reffered as perfectly normally distributed.

# %%
df['Age'].plot(kind='box')
# Out:
# <Axes: >

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
df[df['Age'] > 65]
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 33            34         0       2                 Wheadon, Mr. Edward H
# 96            97         0       1             Goldschmidt, Mr. George B
# 116          117         0       3                  Connors, Mr. Patrick
# 493          494         0       1               Artagaveytia, Mr. Ramon
# 630          631         1       1  Barkworth, Mr. Algernon Henry Wilson
# 672          673         0       2           Mitchell, Mr. Henry Michael
# 745          746         0       1          Crosby, Capt. Edward Gifford
# 851          852         0       3                   Svensson, Mr. Johan
#
#       Sex   Age  SibSp  Parch      Ticket     Fare Cabin Embarked
# 33   male  66.0      0      0  C.A. 24579  10.5000   NaN        S
# 96   male  71.0      0      0    PC 17754  34.6542    A5        C
# 116  male  70.5      0      0      370369   7.7500   NaN        Q
# ...

# %%
df['Age'].isnull().sum()
# Out:
# np.int64(177)

# %%
df['Age'].isnull().sum()/len(df['Age'])
# Out:
# np.float64(0.19865319865319866)

# %% [markdown]
# around 19% missing values in the dataset

# %% [markdown]
# **conclusions**
#
# - Age is normally(almost) distributed
# - 20% of the values are missing
# - There are some outliers

# %% [markdown]
# ### Fare

# %%
df['Fare'].describe()
# Out:
# count    891.000000
# mean      32.204208
# std       49.693429
# min        0.000000
# 25%        7.910400
# 50%       14.454200
# 75%       31.000000
# max      512.329200
# Name: Fare, dtype: float64

# %%
df['Fare'].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# - Not normally distributed at all

# %%
df['Fare'].plot(kind='kde')

# %% [markdown]
# - data is skeweed

# %%
df['Fare'].skew()
# Out:
# np.float64(4.787316519674893)

# %% [markdown]
# We cannot directly run the statistical test assuming it is a normally distributed as it is currently positively skeweed

# %%
df['Fare'].plot(kind='box')
# Out:
# <Axes: >

# %%
df[df['Fare'] > 250]
# Out:
#      PassengerId  Survived  Pclass                                   Name  \
# 27            28         0       1         Fortune, Mr. Charles Alexander
# 88            89         1       1             Fortune, Miss. Mabel Helen
# 258          259         1       1                       Ward, Miss. Anna
# 311          312         1       1             Ryerson, Miss. Emily Borie
# 341          342         1       1         Fortune, Miss. Alice Elizabeth
# 438          439         0       1                      Fortune, Mr. Mark
# 679          680         1       1     Cardeza, Mr. Thomas Drake Martinez
# 737          738         1       1                 Lesurer, Mr. Gustave J
# 742          743         1       1  Ryerson, Miss. Susan Parker "Suzette"
#
#         Sex   Age  SibSp  Parch    Ticket      Fare            Cabin Embarked
# 27     male  19.0      3      2     19950  263.0000      C23 C25 C27        S
# ...

# %% [markdown]
# The fare column value is not an individual fare rather it is a group fair or family fair as a whole

# %%
df['Fare'].isnull().sum()
# Out:
# np.int64(0)

# %% [markdown]
# **conclusions**
#
# - The data is highly(positively) skewed
# - Fare col actually contains the group fare and not the individual fare(This migth be an issue)
# - We need to create a new col called individual fare

# %% [markdown]
# ### Steps of doing Univariate Analysis on Categorical columns
#
# **Descriptive Statistics**: Compute the frequency distribution of the categories in the column. This will give a general understanding of the distribution of the categories and their relative frequencies.
#
# **Visualizations**: Create visualizations to explore the distribution of the categories. Some common visualizations for categorical data include count plots and pie charts. These visualizations provide a visual representation of the distribution of the categories and can help identify any patterns or anomalies in the data.
#
# **Missing Values**: Check for missing values in the data and decide how to handle them. Missing values can be imputed or excluded from the analysis, depending on the research question and the data set.
#
# **Conclusion**: Summarize the findings of the EDA and make decisions about how to proceed with further analysis.

# %% [markdown]
# ### Survived column

# %%
df['Survived'].value_counts()
# Out:
# Survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %%
df['Survived'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Survived'>

# %%
df['Survived'].value_counts().plot(kind='pie', autopct='%.2f%%')
# Out:
# <Axes: ylabel='count'>

# %%
df['Survived'].isnull().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ### Survived
#
# **conclusions**
#
# - More than 60% of the passengers didn't survive the accident.

# %% [markdown]
# ### PClass

# %%
df['Pclass'].value_counts()
# Out:
# Pclass
# 3    491
# 1    216
# 2    184
# Name: count, dtype: int64

# %%
df['Pclass'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Pclass'>

# %%
df['Pclass'].value_counts().plot(kind='pie', autopct='%.2f%%')
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# ### PClass
# **conclusions**
#
# - Surprising more people are travelling in class 3 which is the most expensive class than class 2 and as usual most of the passsengers are travelling in Class 3.

# %% [markdown]
# ### Sex

# %%
df["Sex"].value_counts()
# Out:
# Sex
# male      577
# female    314
# Name: count, dtype: int64

# %%
df['Sex'].value_counts().plot(kind='pie', autopct='%.2f%%')
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# ### Check for SibSp Cols as well

# %%
df['SibSp'].value_counts()
# Out:
# SibSp
# 0    608
# 1    209
# 2     28
# 4     18
# 3     16
# 8      7
# 5      5
# Name: count, dtype: int64

# %%
df['Parch'].value_counts()
# Out:
# Parch
# 0    678
# 1    118
# 2     80
# 5      5
# 3      5
# 4      4
# 6      1
# Name: count, dtype: int64

# %% [markdown]
# ### SibSp and Parch
#
# **conclusions**
#
# - Parch and SibSp cols can be merged to form  a new col call family_size
# - Create a new col called is_alone

# %%
df['Embarked'].value_counts()
# Out:
# Embarked
# S    644
# C    168
# Q     77
# Name: count, dtype: int64

# %%
df['Embarked'].value_counts().plot(kind='pie',autopct='%0.1f%%')
# Out:
# <Axes: ylabel='count'>

# %%
df['Fare'].isnull().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ### Univariate Analysis on Mixed Column
#
# - need to feature engineer the columns to get conclusion of the mixed columns

# %% [markdown]
# ### Steps of doing Bivariate Analysis
#
# - Select/Choose 2 cols
# - Understand type of relationship
#     1. **Numerical - Numerical**<br>
#         a. You can plot graphs like scatterplot(regression plots), 2D histplot, 2D KDEplots<br>
#         b. Check correlation coefficent to check linear relationship
#     2. **Numerical - Categorical** - create visualizations that compare the distribution of the numerical data across different categories of the categorical data.<br>
#         a. You can plot graphs like barplot, boxplot, kdeplot violinplot even scatterplots<br>
#     3. **Categorical - Categorical**<br>
#         a. You can create cross-tabulations or contingency tables that show the distribution of values in one categorical column, grouped by the values in the other categorical column.<br>
#         b. You can plots like heatmap, stacked barplots, treemaps
#
# - Write your conclusions

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# ### Survied and Pclass  --- both are categorical
#
# how many survived form each of the class

# %%
## contigency table and crosstab

pd.crosstab(df['Survived'],df['Pclass'])
# Out:
# Pclass      1   2    3
# Survived
# 0          80  97  372
# 1         136  87  119

# %%
## on the basis of percentage

pd.crosstab(df['Survived'],df['Pclass'],normalize='columns')*100
# Out:
# Pclass            1          2          3
# Survived
# 0         37.037037  52.717391  75.763747
# 1         62.962963  47.282609  24.236253

# %% [markdown]
# ### Conclusion
# - We find that the highest percentage of death is in Pclass 3 and survive rate is in Pclass 1.
# - To travel on Pclass 1 was safer and has highest survived rate

# %%
sns.heatmap(pd.crosstab(df['Survived'],df['Pclass'],normalize='columns')*100)
# Out:
# <Axes: xlabel='Pclass', ylabel='Survived'>

# %%
## Survived and sex bivariate analysis

pd.crosstab(df['Survived'],df['Sex'],normalize='columns')*100
# Out:
# Sex          female       male
# Survived
# 0         25.796178  81.109185
# 1         74.203822  18.890815

# %%
pd.crosstab(df['Survived'],df['Embarked'],normalize='columns')*100
# Out:
# Embarked          C          Q          S
# Survived
# 0         44.642857  61.038961  66.304348
# 1         55.357143  38.961039  33.695652

# %% [markdown]
# #### Conclusion
#
# - Somewhat from Embark category who got onboard from Chebork has highest survived rate might be they are from Pclass1 or are female

# %%
pd.crosstab(df['Sex'],df['Embarked'],normalize='columns')*100
# Out:
# Embarked          C          Q          S
# Sex
# female    43.452381  46.753247  31.521739
# male      56.547619  53.246753  68.478261

# %% [markdown]
# not because of the gender as they are almost same and male are more in number

# %%
pd.crosstab(df['Pclass'],df['Embarked'],normalize='columns')*100
# Out:
# Embarked          C          Q          S
# Pclass
# 1         50.595238   2.597403  19.720497
# 2         10.119048   3.896104  25.465839
# 3         39.285714  93.506494  54.813665

# %% [markdown]
# ### (Survived )categorical with numerical columns (age)

# %%
# survived and age

df[df['Survived'] == 1]['Age'].plot(kind='kde',label='Survived')
df[df['Survived'] == 0]['Age'].plot(kind='kde',label='Not Survived')

plt.legend() ## to show labels
plt.show()

# %% [markdown]
# ##### Conclusions
#
# - from this graph we can conclude that age is a factor in the survival rate as the age group near to 0 who are childrens have more chance of survial, whearas 20-40 has lesser change
# - also around age of 40  the survival rate is little higher might be they belong of Pclass 1 so lets check age to conclude if it is so or not

# %%
df[df['Pclass'] == 1]['Age'].mean()
# Out:
# np.float64(38.233440860215055)

# %% [markdown]
# ### Feature Engineering on Fare col

# %%
df['SibSp'].value_counts()
# Out:
# SibSp
# 0    608
# 1    209
# 2     28
# 4     18
# 3     16
# 8      7
# 5      5
# Name: count, dtype: int64

# %%
df[df["SibSp"] == 8]
# Out:
#      PassengerId  Survived  Pclass                               Name     Sex  \
# 159          160         0       3         Sage, Master. Thomas Henry    male
# 180          181         0       3       Sage, Miss. Constance Gladys  female
# 201          202         0       3                Sage, Mr. Frederick    male
# 324          325         0       3           Sage, Mr. George John Jr    male
# 792          793         0       3            Sage, Miss. Stella Anna  female
# 846          847         0       3           Sage, Mr. Douglas Bullen    male
# 863          864         0       3  Sage, Miss. Dorothy Edith "Dolly"  female
#
#      Age  SibSp  Parch    Ticket   Fare Cabin Embarked
# 159  NaN      8      2  CA. 2343  69.55   NaN        S
# 180  NaN      8      2  CA. 2343  69.55   NaN        S
# 201  NaN      8      2  CA. 2343  69.55   NaN        S
# 324  NaN      8      2  CA. 2343  69.55   NaN        S
# 792  NaN      8      2  CA. 2343  69.55   NaN        S
# ...

# %%
df[df['Ticket'] == 'CA. 2343']
# Out:
#      PassengerId  Survived  Pclass                               Name     Sex  \
# 159          160         0       3         Sage, Master. Thomas Henry    male
# 180          181         0       3       Sage, Miss. Constance Gladys  female
# 201          202         0       3                Sage, Mr. Frederick    male
# 324          325         0       3           Sage, Mr. George John Jr    male
# 792          793         0       3            Sage, Miss. Stella Anna  female
# 846          847         0       3           Sage, Mr. Douglas Bullen    male
# 863          864         0       3  Sage, Miss. Dorothy Edith "Dolly"  female
#
#      Age  SibSp  Parch    Ticket   Fare Cabin Embarked
# 159  NaN      8      2  CA. 2343  69.55   NaN        S
# 180  NaN      8      2  CA. 2343  69.55   NaN        S
# 201  NaN      8      2  CA. 2343  69.55   NaN        S
# 324  NaN      8      2  CA. 2343  69.55   NaN        S
# 792  NaN      8      2  CA. 2343  69.55   NaN        S
# ...

# %%
df[df['Name'].str.contains('Sage')]
# Out:
#      PassengerId  Survived  Pclass                               Name     Sex  \
# 159          160         0       3         Sage, Master. Thomas Henry    male
# 180          181         0       3       Sage, Miss. Constance Gladys  female
# 201          202         0       3                Sage, Mr. Frederick    male
# 324          325         0       3           Sage, Mr. George John Jr    male
# 641          642         1       1               Sagesser, Mlle. Emma  female
# 792          793         0       3            Sage, Miss. Stella Anna  female
# 846          847         0       3           Sage, Mr. Douglas Bullen    male
# 863          864         0       3  Sage, Miss. Dorothy Edith "Dolly"  female
#
#       Age  SibSp  Parch    Ticket   Fare Cabin Embarked
# 159   NaN      8      2  CA. 2343  69.55   NaN        S
# 180   NaN      8      2  CA. 2343  69.55   NaN        S
# 201   NaN      8      2  CA. 2343  69.55   NaN        S
# ...

# %%
df1 = pd.read_csv('test.csv')
df1
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# ...

# %%
df = pd.concat([df,df1])

# %%
df[df['Ticket'] == 'CA. 2343']
# Out:
#      PassengerId  Survived  Pclass                               Name     Sex  \
# 159          160       0.0       3         Sage, Master. Thomas Henry    male
# 180          181       0.0       3       Sage, Miss. Constance Gladys  female
# 201          202       0.0       3                Sage, Mr. Frederick    male
# 324          325       0.0       3           Sage, Mr. George John Jr    male
# 792          793       0.0       3            Sage, Miss. Stella Anna  female
# 846          847       0.0       3           Sage, Mr. Douglas Bullen    male
# 863          864       0.0       3  Sage, Miss. Dorothy Edith "Dolly"  female
# 188         1080       NaN       3                    Sage, Miss. Ada  female
# 342         1234       NaN       3              Sage, Mr. John George    male
# 360         1252       NaN       3        Sage, Master. William Henry    male
# 365         1257       NaN       3     Sage, Mrs. John (Annie Bullen)  female
#
# ...

# %%
df['Ticket'].value_counts()
# Out:
# Ticket
# CA. 2343        11
# 1601             8
# CA 2144          8
# 347082           7
# S.O.C. 14879     7
#                 ..
# A.5. 3236        1
# 347086           1
# 365237           1
# 334915           1
# 28666            1
# Name: count, Length: 929, dtype: int64

# %%
df[df["Ticket"] == 'CA 2144']
# Out:
#      PassengerId  Survived  Pclass                                     Name  \
# 59            60       0.0       3       Goodwin, Master. William Frederick
# 71            72       0.0       3               Goodwin, Miss. Lillian Amy
# 386          387       0.0       3          Goodwin, Master. Sidney Leonard
# 480          481       0.0       3           Goodwin, Master. Harold Victor
# 678          679       0.0       3  Goodwin, Mrs. Frederick (Augusta Tyler)
# 683          684       0.0       3              Goodwin, Mr. Charles Edward
# 139         1031       NaN       3           Goodwin, Mr. Charles Frederick
# 140         1032       NaN       3              Goodwin, Miss. Jessie Allis
#
#         Sex   Age  SibSp  Parch   Ticket  Fare Cabin Embarked
# 59     male  11.0      5      2  CA 2144  46.9   NaN        S
# 71   female  16.0      5      2  CA 2144  46.9   NaN        S
# 386    male   1.0      5      2  CA 2144  46.9   NaN        S
# ...

# %%
df['individual_fare'] = df['Fare']/(df['SibSp'] + df['Parch'] + 1)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1       0.0       3
# 1              2       1.0       1
# 2              3       1.0       3
# 3              4       1.0       1
# 4              5       0.0       3
# ..           ...       ...     ...
# 413         1305       NaN       3
# 414         1306       NaN       1
# 415         1307       NaN       3
# 416         1308       NaN       3
# 417         1309       NaN       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df['individual_fare'].plot(kind='box')
# Out:
# <Axes: >

# %%
df[['individual_fare','Fare']].describe()
# Out:
#        individual_fare         Fare
# count      1308.000000  1308.000000
# mean         20.518215    33.295479
# std          35.774337    51.758668
# min           0.000000     0.000000
# 25%           7.452767     7.895800
# 50%           8.512483    14.454200
# 75%          24.237500    31.275000
# max         512.329200   512.329200

# %% [markdown]
# ### family_size --->> SibSp and Parch

# %%
df['family_size'] = df['SibSp'] + df['Parch'] + 1
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1       0.0       3
# 1              2       1.0       1
# 2              3       1.0       3
# 3              4       1.0       1
# 4              5       0.0       3
# ..           ...       ...     ...
# 413         1305       NaN       3
# 414         1306       NaN       1
# 415         1307       NaN       3
# 416         1308       NaN       3
# 417         1309       NaN       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# ##### family_type, new column
# ##### 1 -> alone
# ##### 2-4 -> small
# ##### >5 -> large

# %%
def transform_family_size(num):

  if num == 1:
    return 'alone'
  elif num>1 and num <5:
    return "small"
  else:
    return "large"

# %%
df['family_type'] = df['family_size'].apply(transform_family_size)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1       0.0       3
# 1              2       1.0       1
# 2              3       1.0       3
# 3              4       1.0       1
# 4              5       0.0       3
# ..           ...       ...     ...
# 413         1305       NaN       3
# 414         1306       NaN       1
# 415         1307       NaN       3
# 416         1308       NaN       3
# 417         1309       NaN       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
pd.crosstab(df['Survived'],df['family_type'],normalize='columns')*100
# Out:
# family_type      alone      large      small
# Survived
# 0.0          69.646182  83.870968  42.123288
# 1.0          30.353818  16.129032  57.876712

# %% [markdown]
# ### working with name column
#
# - can be useful to find that passenger belongs too which family and check their survival rate

# %%
df['Name'].str.split(',')
# Out:
# 0                             [Braund,  Mr. Owen Harris]
# 1      [Cumings,  Mrs. John Bradley (Florence Briggs ...
# 2                              [Heikkinen,  Miss. Laina]
# 3        [Futrelle,  Mrs. Jacques Heath (Lily May Peel)]
# 4                            [Allen,  Mr. William Henry]
#                              ...
# 413                                [Spector,  Mr. Woolf]
# 414                      [Oliva y Ocana,  Dona. Fermina]
# 415                      [Saether,  Mr. Simon Sivertsen]
# 416                               [Ware,  Mr. Frederick]
# 417                          [Peter,  Master. Michael J]
# Name: Name, Length: 1309, dtype: object

# %%
df['surname'] = df['Name'].str.split(',').str.get(0)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1       0.0       3
# 1              2       1.0       1
# 2              3       1.0       3
# 3              4       1.0       1
# 4              5       0.0       3
# ..           ...       ...     ...
# 413         1305       NaN       3
# 414         1306       NaN       1
# 415         1307       NaN       3
# 416         1308       NaN       3
# 417         1309       NaN       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df['Name'].str.split(',').str.get(1).str.strip().str.split(' ').str.get(0)
# Out:
# 0          Mr.
# 1         Mrs.
# 2        Miss.
# 3         Mrs.
# 4          Mr.
#         ...
# 413        Mr.
# 414      Dona.
# 415        Mr.
# 416        Mr.
# 417    Master.
# Name: Name, Length: 1309, dtype: object

# %%
df['title'] = df['Name'].str.split(',').str.get(1).str.strip().str.split(' ').str.get(0)
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1       0.0       3
# 1              2       1.0       1
# 2              3       1.0       3
# 3              4       1.0       1
# 4              5       0.0       3
# ..           ...       ...     ...
# 413         1305       NaN       3
# 414         1306       NaN       1
# 415         1307       NaN       3
# 416         1308       NaN       3
# 417         1309       NaN       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df['title'].value_counts()
# Out:
# title
# Mr.         757
# Miss.       260
# Mrs.        197
# Master.      61
# Other.       17
# Dr.           8
# Ms.           2
# Otheror.      2
# Mlle.         2
# Mme.          1
# the           1
# Othera.       1
# Name: count, dtype: int64

# %%
df['title'] = df['title'].str.replace(r'\b(Rev|Col|Maj|Jonkheer|Major|Capt|Don|Sir|Lady|Countess|Dr)[. ]?\b', 'Other', regex=True)
df['title'].value_counts()
# Out:
# title
# Mr.         757
# Miss.       260
# Mrs.        197
# Master.      61
# Other.       25
# Ms.           2
# Otheror.      2
# Mlle.         2
# Mme.          1
# the           1
# Othera.       1
# Name: count, dtype: int64

# %%
temp_df = df[df['title'].isin(['Mr.','Miss.','Mrs.','Master.','Other.'])]

# %%
pd.crosstab(temp_df['Survived'],temp_df['title'],normalize='columns')*100
# Out:
# title     Master.     Miss.        Mr.  Mrs.  Other.
# Survived
# 0.0          42.5  30.21978  84.332689  20.8    70.0
# 1.0          57.5  69.78022  15.667311  79.2    30.0

# %% [markdown]
# ### Cabin col

# %%
df['Cabin'].isnull().sum()
# Out:
# np.int64(1014)

# %%
df['Cabin'].isnull().sum()/len(df['Cabin'])
# Out:
# np.float64(0.774637127578304)

# %%
df['Cabin'].value_counts().head(15)
# Out:
# Cabin
# C23 C25 C27        6
# G6                 5
# B57 B59 B63 B66    5
# F33                4
# F4                 4
# C78                4
# D                  4
# F2                 4
# B96 B98            4
# C22 C26            4
# A34                3
# E34                3
# C101               3
# B51 B53 B55        3
# E101               3
# Name: count, dtype: int64

# %%
df['Cabin'].fillna('M',inplace=True)

# %%
df['Cabin'].value_counts()
# Out:
# Cabin
# M                  1014
# C23 C25 C27           6
# G6                    5
# B57 B59 B63 B66       5
# F33                   4
#                    ...
# C39                   1
# B24                   1
# D40                   1
# D38                   1
# C105                  1
# Name: count, Length: 187, dtype: int64

# %%
df['deck'] = df['Cabin'].str[0]

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1       0.0       3
# 1              2       1.0       1
# 2              3       1.0       3
# 3              4       1.0       1
# 4              5       0.0       3
# ..           ...       ...     ...
# 413         1305       NaN       3
# 414         1306       NaN       1
# 415         1307       NaN       3
# 416         1308       NaN       3
# 417         1309       NaN       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df['deck'].value_counts()
# Out:
# deck
# M    1014
# C      94
# B      65
# D      46
# E      41
# A      22
# F      21
# G       5
# T       1
# Name: count, dtype: int64

# %%
pd.crosstab(df['deck'],df['Pclass'])
# Out:
# Pclass   1    2    3
# deck
# A       22    0    0
# B       65    0    0
# C       94    0    0
# D       40    6    0
# E       34    4    3
# F        0   13    8
# G        0    0    5
# M       67  254  693
# T        1    0    0

# %%
pd.crosstab(df['Survived'], df['deck'], normalize='columns')*100
# Out:
# deck              A          B          C          D     E          F     G  \
# Survived
# 0.0       53.333333  25.531915  40.677966  24.242424  25.0  38.461538  50.0
# 1.0       46.666667  74.468085  59.322034  75.757576  75.0  61.538462  50.0
#
# deck              M      T
# Survived
# 0.0       70.014556  100.0
# 1.0       29.985444    0.0

# %%
pd.crosstab(df['deck'],df['Survived'],normalize='index').plot(kind='bar',stacked=True)
# Out:
# <Axes: xlabel='deck'>

# %% [markdown]
# - The survival rate depends on the which deck are they travelling as well

# %% [markdown]
# #### corr
#
# - provides an overview about how one column is dependent and is realted with other columns, basically provides the correlation between the columns

# %%
df.select_dtypes(include='number').corr()
# Out:
#                  PassengerId  Survived    Pclass       Age     SibSp  \
# PassengerId         1.000000 -0.005007 -0.038354  0.028814 -0.055224
# Survived           -0.005007  1.000000 -0.338481 -0.077221 -0.035322
# Pclass             -0.038354 -0.338481  1.000000 -0.408106  0.060832
# Age                 0.028814 -0.077221 -0.408106  1.000000 -0.243699
# SibSp              -0.055224 -0.035322  0.060832 -0.243699  1.000000
# Parch               0.008942  0.081629  0.018322 -0.150917  0.373587
# Fare                0.031428  0.257307 -0.558629  0.178740  0.160238
# individual_fare     0.035365  0.221600 -0.504270  0.193545 -0.089807
# family_size        -0.031437  0.016639  0.050027 -0.240229  0.861952
#
#                     Parch      Fare  individual_fare  family_size
# PassengerId      0.008942  0.031428         0.035365    -0.031437
# Survived         0.081629  0.257307         0.221600     0.016639
# Pclass           0.018322 -0.558629        -0.504270     0.050027
# ...

# %%
df.select_dtypes(include='number').corr()['Survived']
# Out:
# PassengerId       -0.005007
# Survived           1.000000
# Pclass            -0.338481
# Age               -0.077221
# SibSp             -0.035322
# Parch              0.081629
# Fare               0.257307
# individual_fare    0.221600
# family_size        0.016639
# Name: Survived, dtype: float64

# %%
sns.heatmap(df.select_dtypes(include='number').corr())
# Out:
# <Axes: >

# %%
sns.pairplot(df1)

# %%
df1
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# ...
