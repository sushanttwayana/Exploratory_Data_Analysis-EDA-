# %% [markdown]
# ### What is Pandas
#
# Pandas is a fast, powerful, flexible and easy to use open source data analysis and manipulation tool,
# built on top of the Python programming language.
#
# https://pandas.pydata.org/about/index.html

# %% [markdown]
# ### Pandas Series
#
# A Pandas Series is like a column in a table. It is a 1-D array holding data of any type.

# %% [markdown]
# ### Importing Pandas

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### Series from lists

# %%
# string type series
country = ['Nepal','US','India','USA','Australia','Srilanka']

pd.Series(country)
# Out:
# 0        Nepal
# 1           US
# 2        India
# 3          USA
# 4    Australia
# 5     Srilanka
# dtype: object

# %%
# integers
runs = [13,24,56,78,100]

runs_ser = pd.Series(runs)

runs_ser
# Out:
# 0     13
# 1     24
# 2     56
# 3     78
# 4    100
# dtype: int64

# %%
# custom index : we can define our own index
marks = [67,57,89,100]
subjects = ['maths','english','science','nepali']

pd.Series(marks,index=subjects)
# Out:
# maths       67
# english     57
# science     89
# nepali     100
# dtype: int64

# %%
# setting a name
marks = pd.Series(marks,index=subjects,name='ram ko marks')
marks
# Out:
# maths       67
# english     57
# science     89
# nepali     100
# Name: ram ko marks, dtype: int64

# %% [markdown]
# ### Series from dict

# %%
marks = {
    'maths':67,
    'english':57,
    'science':89,
    'nepali':100
}

marks_series = pd.Series(marks,name='ram ko marks')
marks_series
# Out:
# maths       67
# english     57
# science     89
# nepali     100
# Name: ram ko marks, dtype: int64

# %% [markdown]
# ### Series Attributes

# %% [markdown]
# #### size : number of items in the object

# %%
marks_series.size
# Out:
# 4

# %% [markdown]
# #### dtype: datatype of the object

# %%
marks_series.dtype
# Out:
# dtype('int64')

# %%
# name
marks_series.name
# Out:
# 'ram ko marks'

# %% [markdown]
# #### is_unique:
#
# - Check and return that if the elements of the series object are unique or not

# %%
marks_series.is_unique
# Out:
# True

# %%
pd.Series([1,1,2,3,4,5]).is_unique
# Out:
# False

# %% [markdown]
# #### index:
#
# - at once return the index object with all the index values stored

# %%
marks_series.index
# Out:
# Index(['maths', 'english', 'science', 'nepali'], dtype='object')

# %%
runs_ser.index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %% [markdown]
# #### values:
#
# - Returns the values from the series

# %%
marks_series.values
# Out:
# array([ 67,  57,  89, 100])

# %% [markdown]
# ### Series using read_csv

# %%
# with one col
subs = pd.read_csv('./dataset/subs.csv')
subs.head()
# Out:
#    Follower Gained
# 0               48
# 1               57
# 2               40
# 3               43
# 4               44

# %%
type(pd.read_csv('./dataset/subs.csv'))
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ### squeeze()
#
# - converts the dataframe which is default into series

# %%
pd.read_csv('./dataset/subs.csv').squeeze()
# Out:
# 0       48
# 1       57
# 2       40
# 3       43
# 4       44
#       ...
# 360    231
# 361    226
# 362    155
# 363    144
# 364    172
# Name: Follower Gained, Length: 365, dtype: int64

# %%
type(pd.read_csv('./dataset/subs.csv').squeeze())
# Out:
# pandas.core.series.Series

# %%
# with 2 cols
ronaldo_goals = pd.read_csv('./dataset/ronaldo_goals.csv',index_col='year').squeeze()
ronaldo_goals
# Out:
# year
# 2002     5
# 2003     1
# 2004    13
# 2005    15
# 2006    25
# 2007    34
# 2008    35
# 2009    30
# 2010    48
# 2011    60
# 2012    63
# 2013    69
# 2014    61
# 2015    57
# 2016    55
# 2017    53
# 2018    49
# 2019    39
# 2020    44
# 2021    47
# 2022    16
# 2023    54
# 2024    43
# 2025    41
# Name: number_of_goals_scored, dtype: int64

# %%
movies = pd.read_csv('./dataset/bollywood.csv',index_col='movie').squeeze()
movies
# Out:
# movie
# Uri: The Surgical Strike                   Vicky Kaushal
# Battalion 609                                Vicky Ahuja
# The Accidental Prime Minister (film)         Anupam Kher
# Why Cheat India                            Emraan Hashmi
# Evening Shadows                         Mona Ambegaonkar
#                                               ...
# Hum Tumhare Hain Sanam                    Shah Rukh Khan
# Aankhen (2002 film)                     Amitabh Bachchan
# Saathiya (film)                             Vivek Oberoi
# Company (film)                                Ajay Devgn
# Awara Paagal Deewana                        Akshay Kumar
# Name: lead, Length: 1500, dtype: object

# %% [markdown]
# ### Series methods

# %%
# head and tail
subs.head() ## default 5 rows
# Out:
#    Follower Gained
# 0               48
# 1               57
# 2               40
# 3               43
# 4               44

# %%
ronaldo_goals.head(3)
# Out:
# year
# 2002     5
# 2003     1
# 2004    13
# Name: number_of_goals_scored, dtype: int64

# %%
ronaldo_goals.tail(10)
# Out:
# year
# 2016    55
# 2017    53
# 2018    49
# 2019    39
# 2020    44
# 2021    47
# 2022    16
# 2023    54
# 2024    43
# 2025    41
# Name: number_of_goals_scored, dtype: int64

# %% [markdown]
# ### sample()
#
# - Randomly samples the output as specified

# %%
movies.sample()
# Out:
# movie
# Rangoon (2017 Hindi film)    Kangana Ranaut
# Name: lead, dtype: object

# %%
# sample
movies.sample(5)
# Out:
# movie
# Haseena Parkar                     Shraddha Kapoor
# Jal (film)                             Purab Kohli
# Ek Khiladi Ek Haseena (film)          Fardeen Khan
# M Cream                                  Tom Alter
# Mr. Singh Mrs. Mehta            Prashant Narayanan
# Name: lead, dtype: object

# %% [markdown]
# ### value_counts
#
# - returns the frequency of each item in the dataset

# %%
# value_counts -> movies
movies.value_counts()
# Out:
# lead
# Akshay Kumar            48
# Amitabh Bachchan        45
# Ajay Devgn              38
# Salman Khan             31
# Sanjay Dutt             26
#                         ..
# Tanishaa Mukerji         1
# Tanuja                   1
# Ankit                    1
# Rakhee Gulzar            1
# Geetika Vidya Ohlyan     1
# Name: count, Length: 566, dtype: int64

# %% [markdown]
# ### sort_values()
#
# - sort the series values in ascending order

# %%
ronaldo_goals.sort_values()
# Out:
# year
# 2003     1
# 2002     5
# 2004    13
# 2005    15
# 2022    16
# 2006    25
# 2009    30
# 2007    34
# 2008    35
# 2019    39
# 2025    41
# 2024    43
# 2020    44
# 2021    47
# 2010    48
# 2018    49
# 2017    53
# 2023    54
# 2016    55
# 2015    57
# 2011    60
# 2014    61
# 2012    63
# 2013    69
# Name: number_of_goals_scored, dtype: int64

# %%
ronaldo_goals.sort_values(ascending=False).head(5)
# Out:
# year
# 2013    69
# 2012    63
# 2014    61
# 2011    60
# 2015    57
# Name: number_of_goals_scored, dtype: int64

# %%
# sort_values -> inplace
ronaldo_goals.sort_values(ascending=False).head(1).values[0]
# Out:
# np.int64(69)

# %%
ronaldo_goals
# Out:
# year
# 2002     5
# 2003     1
# 2004    13
# 2005    15
# 2006    25
# 2007    34
# 2008    35
# 2009    30
# 2010    48
# 2011    60
# 2012    63
# 2013    69
# 2014    61
# 2015    57
# 2016    55
# 2017    53
# 2018    49
# 2019    39
# 2020    44
# 2021    47
# 2022    16
# 2023    54
# 2024    43
# 2025    41
# Name: number_of_goals_scored, dtype: int64

# %%
ronaldo_goals_new = ronaldo_goals.copy()
ronaldo_goals_new.sort_values(inplace=True)

# %%
ronaldo_goals_new
# Out:
# year
# 2003     1
# 2002     5
# 2004    13
# 2005    15
# 2022    16
# 2006    25
# 2009    30
# 2007    34
# 2008    35
# 2019    39
# 2025    41
# 2024    43
# 2020    44
# 2021    47
# 2010    48
# 2018    49
# 2017    53
# 2023    54
# 2016    55
# 2015    57
# 2011    60
# 2014    61
# 2012    63
# 2013    69
# Name: number_of_goals_scored, dtype: int64

# %% [markdown]
# ### sort_index()
#
# - sort the index not values

# %%
# sort_index -> inplace -> movies
movies.sort_index(ascending=True,inplace=True)  ## modifies the original series

# %%
movies
# Out:
# movie
# 1920 (film)                   Rajniesh Duggall
# 1920: London                     Sharman Joshi
# 1920: The Evil Returns             Vicky Ahuja
# 1971 (2007 film)                Manoj Bajpayee
# 2 States (2014 film)              Arjun Kapoor
#                                    ...
# Zindagi 50-50                      Veena Malik
# Zindagi Na Milegi Dobara        Hrithik Roshan
# Zindagi Tere Naam           Mithun Chakraborty
# Zokkomon                       Darsheel Safary
# Zor Lagaa Ke...Haiya!            Meghan Jadhav
# Name: lead, Length: 1500, dtype: object

# %%
movies
# Out:
# movie
# Zor Lagaa Ke...Haiya!            Meghan Jadhav
# Zokkomon                       Darsheel Safary
# Zindagi Tere Naam           Mithun Chakraborty
# Zindagi Na Milegi Dobara        Hrithik Roshan
# Zindagi 50-50                      Veena Malik
#                                    ...
# 2 States (2014 film)              Arjun Kapoor
# 1971 (2007 film)                Manoj Bajpayee
# 1920: The Evil Returns             Vicky Ahuja
# 1920: London                     Sharman Joshi
# 1920 (film)                   Rajniesh Duggall
# Name: lead, Length: 1500, dtype: object

# %% [markdown]
# ### Series Maths Methods

# %% [markdown]
# ### count()
#
# - total number of items present inside the series but doesn't include the misssing value where size does include the missing values as well

# %%
# count
ronaldo_goals.count()
# Out:
# np.int64(24)

# %%
# sum -> product
ronaldo_goals.sum()
# Out:
# np.int64(957)

# %%
subs.product()
# Out:
# Follower Gained    0
# dtype: int64

# %%
# mean -> median -> mode -> std -> var
subs.mean()
print(ronaldo_goals.median())
print(movies.mode()) ## actor with maximum number of movies returns 0 which is index
print(subs.std()) ## returns standard deviation
print(ronaldo_goals.var()) ### return variance
# Out:
# 43.5
# 0    Akshay Kumar
# Name: lead, dtype: object
# Follower Gained    62.675023
# dtype: float64
# 364.0271739130435

# %%
# min/max
ronaldo_goals.max()
# Out:
# np.int64(69)

# %%
# describe
ronaldo_goals.describe()
# Out:
# count    24.000000
# mean     39.875000
# std      19.079496
# min       1.000000
# 25%      28.750000
# 50%      43.500000
# 75%      54.250000
# max      69.000000
# Name: number_of_goals_scored, dtype: float64

# %% [markdown]
# ### Series Indexing

# %%
# integer indexing
x = pd.Series([12,13,14,35,46,57,58,79,9])
x
# Out:
# 0    12
# 1    13
# 2    14
# 3    35
# 4    46
# 5    57
# 6    58
# 7    79
# 8     9
# dtype: int64

# %%
x[1]
# Out:
# np.int64(13)

# %%
# negative indexing
x[-1]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File c:\Users\Vanilla\anaconda3\envs\myenv\lib\site-packages\pandas\core\indexes\range.py:413, in RangeIndex.get_loc(self, key)
#     412 try:
# --> 413     return self._range.index(new_key)
#     414 except ValueError as err:
#
# ValueError: -1 is not in range
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[55], line 2
#       1 # negative indexing
# ----> 2 x[-1]
#
# File c:\Users\Vanilla\anaconda3\envs\myenv\lib\site-packages\pandas\core\series.py:1133, in Series.__getitem__(self, key)
#    1130     return self._values[key]
#    1132 elif key_is_scalar:
# -> 1133     return self._get_value(key)
#    1135 # Convert generator to list before going through hashable part
# ...

# %%
movies
# Out:
# movie
# 1920 (film)                   Rajniesh Duggall
# 1920: London                     Sharman Joshi
# 1920: The Evil Returns             Vicky Ahuja
# 1971 (2007 film)                Manoj Bajpayee
# 2 States (2014 film)              Arjun Kapoor
#                                    ...
# Zindagi 50-50                      Veena Malik
# Zindagi Na Milegi Dobara        Hrithik Roshan
# Zindagi Tere Naam           Mithun Chakraborty
# Zokkomon                       Darsheel Safary
# Zor Lagaa Ke...Haiya!            Meghan Jadhav
# Name: lead, Length: 1500, dtype: object

# %%
movies['Zindagi Na Milegi Dobara']
# Out:
# 'Hrithik Roshan'

# %%
movies[-1]
# Out:
# C:\Temp\ipykernel_30036\2731571422.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   movies[-1]
# 'Meghan Jadhav'

# %%
marks_series [-1]
# Out:
# C:\Temp\ipykernel_30036\3120213894.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   marks_series [-1]
# np.int64(100)

# %%
# slicing
ronaldo_goals[5:16]
# Out:
# year
# 2007    34
# 2008    35
# 2009    30
# 2010    48
# 2011    60
# 2012    63
# 2013    69
# 2014    61
# 2015    57
# 2016    55
# 2017    53
# Name: number_of_goals_scored, dtype: int64

# %%
# negative slicing
ronaldo_goals[-5:]
# Out:
# year
# 2021    47
# 2022    16
# 2023    54
# 2024    43
# 2025    41
# Name: number_of_goals_scored, dtype: int64

# %%
movies[::2] ## returns alternate movies jumps of 2
# Out:
# movie
# 1920 (film)                 Rajniesh Duggall
# 1920: The Evil Returns           Vicky Ahuja
# 2 States (2014 film)            Arjun Kapoor
# 3 A.M. (2014 film)             Salil Acharya
# 3 Idiots                          Aamir Khan
#                                   ...
# Zero (2018 film)              Shah Rukh Khan
# Zila Ghaziabad                  Vivek Oberoi
# Zindaggi Rocks                  Sushmita Sen
# Zindagi Na Milegi Dobara      Hrithik Roshan
# Zokkomon                     Darsheel Safary
# Name: lead, Length: 750, dtype: object

# %%
# fancy indexing
ronaldo_goals[[2008, 2013, 2017, 2018]]
# Out:
# year
# 2008    35
# 2013    69
# 2017    53
# 2018    49
# Name: number_of_goals_scored, dtype: int64

# %%
# indexing with labels -> fancy indexing
movies['3 Idiots']
# Out:
# 'Aamir Khan'

# %% [markdown]
# ### Editing Series

# %%
marks_series
# Out:
# maths       67
# english     57
# science     89
# nepali     100
# Name: ram ko marks, dtype: int64

# %%
# using indexing
marks_series[1] = 80
marks_series
# Out:
# C:\Temp\ipykernel_30036\3188237958.py:2: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   marks_series[1] = 80
# maths       67
# english     80
# science     89
# nepali     100
# Name: ram ko marks, dtype: int64

# %%
# what if an index does not exist
marks_series['computer'] = 100

# %%
marks_series
# Out:
# maths        67
# english      80
# science      89
# nepali      100
# computer    100
# Name: ram ko marks, dtype: int64

# %%
runs_ser
# Out:
# 0     13
# 1     24
# 2    100
# 3    100
# 4    100
# dtype: int64

# %%
# slicing -> editing multiple items
runs_ser[2:4] = [50,100]
runs_ser
# Out:
# 0     13
# 1     24
# 2     50
# 3    100
# 4    100
# dtype: int64

# %%
# fancy indexing
runs_ser[[0,3,4]] = [0,0,0]
runs_ser
# Out:
# 0     0
# 1    24
# 2    50
# 3     0
# 4     0
# dtype: int64

# %%
# using index label
movies['3 Idiots'] = 'Kareena Kapoor'
movies
# Out:
# movie
# 1920 (film)                   Rajniesh Duggall
# 1920: London                     Sharman Joshi
# 1920: The Evil Returns             Vicky Ahuja
# 1971 (2007 film)                Manoj Bajpayee
# 2 States (2014 film)              Arjun Kapoor
#                                    ...
# Zindagi 50-50                      Veena Malik
# Zindagi Na Milegi Dobara        Hrithik Roshan
# Zindagi Tere Naam           Mithun Chakraborty
# Zokkomon                       Darsheel Safary
# Zor Lagaa Ke...Haiya!            Meghan Jadhav
# Name: lead, Length: 1500, dtype: object

# %% [markdown]
# ### Series with Python Functionalities

# %%
# len/type/dir/sorted/max/min
print(len(ronaldo_goals)) ## returns total number of items
print(type(ronaldo_goals)) ## returns the type of the series
print(dir(ronaldo_goals)) ## returns all the attributes and methods of the series
print(sorted(ronaldo_goals)) ## returns a sorted list of values in the series
print(min(ronaldo_goals)) ## returns the minimum value in the series
print(max(ronaldo_goals)) ## returns the maximum value in the series
# Out:
# 24
# <class 'pandas.core.series.Series'>
# ...

# %%
type(marks_series)
# Out:
# pandas.core.series.Series

# %%
marks_series
# Out:
# maths        67
# english      80
# science      89
# nepali      100
# computer    100
# Name: ram ko marks, dtype: int64

# %%
# type conversion
list(marks_series)
# Out:
# [67, 80, 89, 100, 100]

# %%
type(marks_series)
# Out:
# pandas.core.series.Series

# %%
dict(marks_series)
# Out:
# {'maths': np.int64(67),
#  'english': np.int64(80),
#  'science': np.int64(89),
#  'nepali': np.int64(100),
#  'computer': np.int64(100)}

# %%
# membership operator

'Inception' in movies  ## default search on index labels
# Out:
# False

# %%
'Alia Bhatt' in movies.values
# Out:
# True

# %%
movies
# Out:
# movie
# 1920 (film)                   Rajniesh Duggall
# 1920: London                     Sharman Joshi
# 1920: The Evil Returns             Vicky Ahuja
# 1971 (2007 film)                Manoj Bajpayee
# 2 States (2014 film)              Arjun Kapoor
#                                    ...
# Zindagi 50-50                      Veena Malik
# Zindagi Na Milegi Dobara        Hrithik Roshan
# Zindagi Tere Naam           Mithun Chakraborty
# Zokkomon                       Darsheel Safary
# Zor Lagaa Ke...Haiya!            Meghan Jadhav
# Name: lead, Length: 1500, dtype: object

# %%
# looping
for i in movies:
  print(i)
# Out:
# Rajniesh Duggall
# Sharman Joshi
# Vicky Ahuja
# Manoj Bajpayee
# Arjun Kapoor
# Barun Sobti
# Salil Acharya
# Naseeruddin Shah
# Kareena Kapoor
# Aisha Ahmed
# Soha Ali Khan
# Akshaye Khanna
# Neil Nitin Mukesh
# Sara Arjun
# Nargis Fakhri
# Mouli Ganguly
# Vipin Sharma
# Priyanka Chopra
# Juhi Chawla
# Atul Kulkarni
# Kunal Khemu
# Shawar Ali
# Kiran Bhatia
# Shabana Azmi
# Jimmy Sheirgill
# Tiger Shroff
# Sidharth Malhotra
# Prabhu Deva
# Neil Nitin Mukesh
# Govinda
# Naveen Bawa
# Amitabh Bachchan
# Shreyas Talpade
# Sudesh Berry
# Madhuri Dixit
# Paul Sidhu
# Ajay Devgn
# Omkar Das Manikpuri
# Shatrughan Sinha
# Arun Bakshi
# Amitabh Bachchan
# Himesh Reshammiya
# Akshaye Khanna
# Priyanshu Chatterjee
# Amitabh Bachchan
# John Abraham
# Emraan Hashmi
# Aditya Roy Kapoor
# Ishaan Manhaas
# Hrishitaa Bhatt
# Sachiin Joshi
# Nana Patekar
# Amitabh Bachchan
# Farooq Shaikh
# Fardeen Khan
# Prabhas
# Akshay Kumar
# Rahul Dev
# Ranbir Kapoor
# Amitabh Bachchan
# Kareena Kapoor
# ...

# %%
for i in movies.index:
  print(i)
# Out:
# 1920 (film)
# 1920: London
# 1920: The Evil Returns
# 1971 (2007 film)
# 2 States (2014 film)
# 22 Yards
# 3 A.M. (2014 film)
# 3 Deewarein
# 3 Idiots
# 3 Storeys
# 31st October (film)
# 36 China Town
# 3G (film)
# 404 (film)
# 5 Weddings
# 68 Pages
# 7 Hours to Go
# 7 Khoon Maaf
# 7½ Phere
# 88 Antop Hill
# 99 (2009 film)
# 99.9 FM (film)
# ?: A Question Mark
# A Decent Arrangement
# A Flat (film)
# A Flying Jatt
# A Gentleman
# ABCD 2
# Aa Dekhen Zara
# Aa Gaya Hero
# Aabra Ka Daabra
# Aag (2007 film)
# Aagey Se Right
# Aaj Ka Andha Kanoon
# Aaja Nachle
# Aakhari Decision
# Aakrosh (2010 film)
# Aalaap (film)
# Aan: Men at Work
# Aanch
# Aankhen (2002 film)
# Aap Kaa Surroor
# Aap Ki Khatir (2006 film)
# Aapko Pehle Bhi Kahin Dekha Hai
# Aarakshan
# Aashayein
# Aashiq Banaya Aapne
# Aashiqui 2
# Aashiqui.in
# Aasma: The Sky Is the Limit
# Aazaan
# Ab Tak Chhappan 2
# Ab Tumhare Hawale Watan Saathiyo
# Accident on Hill Road
# Acid Factory
# Action Jackson (2014 film)
# ...

# %%
# Arithmetic Operators(Broadcasting) -> one scalar value with all items in series
100 - marks_series
# Out:
# maths       33
# english     20
# science     11
# nepali       0
# computer     0
# Name: ram ko marks, dtype: int64

# %%
# Relational Operators

ronaldo_goals >= 50  ## returns boolean series
# Out:
# year
# 2002    False
# 2003    False
# 2004    False
# 2005    False
# 2006    False
# 2007    False
# 2008    False
# 2009    False
# 2010    False
# 2011     True
# 2012     True
# 2013     True
# 2014     True
# 2015     True
# 2016     True
# 2017     True
# 2018    False
# 2019    False
# 2020    False
# 2021    False
# 2022    False
# 2023     True
# 2024    False
# 2025    False
# Name: number_of_goals_scored, dtype: bool

# %% [markdown]
# ### Boolean Indexing on Series

# %%
# Find no of goals scored by ronaldo greater than or equal to 50
ronaldo_goals[ronaldo_goals >= 50].size
# Out:
# 8

# %%
# find number of exact
ronaldo_goals[ronaldo_goals == 0].size
# Out:
# 0

# %%
# find actors who have done more than 20 movies
num_movies = movies.value_counts()
num_movies[num_movies > 20]
# Out:
# lead
# Akshay Kumar        48
# Amitabh Bachchan    45
# Ajay Devgn          38
# Salman Khan         31
# Sanjay Dutt         26
# Shah Rukh Khan      22
# Emraan Hashmi       21
# Name: count, dtype: int64

# %% [markdown]
# ### Plotting Graphs on Series

# %%
ronaldo_goals.plot()
# Out:
# <Axes: xlabel='year'>

# %%
movies.value_counts().head(20).plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# ### Some Important Series Methods

# %%
# astype
# between
# clip
# drop_duplicates
# isnull
# dropna
# fillna
# isin
# apply
# copy

# %%
import numpy as np
import pandas as pd

# %%
# with 2 cols
ronaldo_goals = pd.read_csv('./dataset/ronaldo_goals.csv',index_col='year').squeeze()
ronaldo_goals
# Out:
# year
# 2002     5
# 2003     1
# 2004    13
# 2005    15
# 2006    25
# 2007    34
# 2008    35
# 2009    30
# 2010    48
# 2011    60
# 2012    63
# 2013    69
# 2014    61
# 2015    57
# 2016    55
# 2017    53
# 2018    49
# 2019    39
# 2020    44
# 2021    47
# 2022    16
# 2023    54
# 2024    43
# 2025    41
# Name: number_of_goals_scored, dtype: int64

# %%
movies = pd.read_csv('./dataset/bollywood.csv',index_col='movie').squeeze()
movies
# Out:
# movie
# Uri: The Surgical Strike                   Vicky Kaushal
# Battalion 609                                Vicky Ahuja
# The Accidental Prime Minister (film)         Anupam Kher
# Why Cheat India                            Emraan Hashmi
# Evening Shadows                         Mona Ambegaonkar
#                                               ...
# Hum Tumhare Hain Sanam                    Shah Rukh Khan
# Aankhen (2002 film)                     Amitabh Bachchan
# Saathiya (film)                             Vivek Oberoi
# Company (film)                                Ajay Devgn
# Awara Paagal Deewana                        Akshay Kumar
# Name: lead, Length: 1500, dtype: object

# %%
# astype
import sys
sys.getsizeof(ronaldo_goals)
# Out:
# 400

# %%
sys.getsizeof(ronaldo_goals.astype('int16'))
# Out:
# 256

# %%
# between
ronaldo_goals[ronaldo_goals.between(20,50)].size
# Out:
# 11

# %%
# clip
ronaldo_goals.clip(10,40)
# Out:
# year
# 2002    10
# 2003    10
# 2004    13
# 2005    15
# 2006    25
# 2007    34
# 2008    35
# 2009    30
# 2010    40
# 2011    40
# 2012    40
# 2013    40
# 2014    40
# 2015    40
# 2016    40
# 2017    40
# 2018    40
# 2019    39
# 2020    40
# 2021    40
# 2022    16
# 2023    40
# 2024    40
# 2025    40
# Name: number_of_goals_scored, dtype: int64

# %%
# drop_duplicates
temp = pd.Series([1,1,2,2,3,3,4,4])
temp
# Out:
# 0    1
# 1    1
# 2    2
# 3    2
# 4    3
# 5    3
# 6    4
# 7    4
# dtype: int64

# %%
temp.drop_duplicates(keep='last')
# Out:
# 1    1
# 3    2
# 5    3
# 7    4
# dtype: int64

# %%
temp.duplicated().sum()
# Out:
# np.int64(4)

# %%
ronaldo_goals.duplicated().sum()
# Out:
# np.int64(0)

# %%
movies.drop_duplicates()
# Out:
# movie
# Uri: The Surgical Strike                   Vicky Kaushal
# Battalion 609                                Vicky Ahuja
# The Accidental Prime Minister (film)         Anupam Kher
# Why Cheat India                            Emraan Hashmi
# Evening Shadows                         Mona Ambegaonkar
#                                               ...
# Sssshhh...                              Tanishaa Mukerji
# Rules: Pyaar Ka Superhit Formula                  Tanuja
# Right Here Right Now (film)                        Ankit
# Talaash: The Hunt Begins...                Rakhee Gulzar
# The Pink Mirror                          Edwin Fernandes
# Name: lead, Length: 566, dtype: object

# %%
temp = pd.Series([1,2,3,np.nan,5,6,np.nan,8,np.nan,10])
temp
# Out:
# 0     1.0
# 1     2.0
# 2     3.0
# 3     NaN
# 4     5.0
# 5     6.0
# 6     NaN
# 7     8.0
# 8     NaN
# 9    10.0
# dtype: float64

# %%
temp.size
# Out:
# 10

# %%
temp.count()
# Out:
# np.int64(7)

# %%
# isnull
temp.isnull().sum()
# Out:
# np.int64(3)

# %%
# dropna
temp.dropna()
# Out:
# 0     1.0
# 1     2.0
# 2     3.0
# 4     5.0
# 5     6.0
# 7     8.0
# 9    10.0
# dtype: float64

# %%
# fillna
temp.fillna(temp.mean())
# Out:
# 0     1.0
# 1     2.0
# 2     3.0
# 3     5.0
# 4     5.0
# 5     6.0
# 6     5.0
# 7     8.0
# 8     5.0
# 9    10.0
# dtype: float64

# %%
# isin
ronaldo_goals[(ronaldo_goals == 57) | (ronaldo_goals == 63)]
# Out:
# year
# 2012    63
# 2015    57
# Name: number_of_goals_scored, dtype: int64

# %%
ronaldo_goals[ronaldo_goals.isin([57, 60])]
# Out:
# year
# 2011    60
# 2015    57
# Name: number_of_goals_scored, dtype: int64

# %%
# apply
movies
# Out:
# movie
# Uri: The Surgical Strike                   Vicky Kaushal
# Battalion 609                                Vicky Ahuja
# The Accidental Prime Minister (film)         Anupam Kher
# Why Cheat India                            Emraan Hashmi
# Evening Shadows                         Mona Ambegaonkar
#                                               ...
# Hum Tumhare Hain Sanam                    Shah Rukh Khan
# Aankhen (2002 film)                     Amitabh Bachchan
# Saathiya (film)                             Vivek Oberoi
# Company (film)                                Ajay Devgn
# Awara Paagal Deewana                        Akshay Kumar
# Name: lead, Length: 1500, dtype: object

# %%
movies.apply(lambda x:x.split()[0].upper())
# Out:
# movie
# Uri: The Surgical Strike                  VICKY
# Battalion 609                             VICKY
# The Accidental Prime Minister (film)     ANUPAM
# Why Cheat India                          EMRAAN
# Evening Shadows                            MONA
#                                          ...
# Hum Tumhare Hain Sanam                     SHAH
# Aankhen (2002 film)                     AMITABH
# Saathiya (film)                           VIVEK
# Company (film)                             AJAY
# Awara Paagal Deewana                     AKSHAY
# Name: lead, Length: 1500, dtype: object

# %%
# with one col
followers = pd.read_csv('./dataset/subs.csv').squeeze()
followers.head()
# Out:
# 0    48
# 1    57
# 2    40
# 3    43
# 4    44
# Name: Follower Gained, dtype: int64

# %%
mean_val = followers.mean()

followers.apply(
    lambda x: 'good day' if x > mean_val else 'bad day'
)
# Out:
# 0       bad day
# 1       bad day
# 2       bad day
# 3       bad day
# 4       bad day
#          ...
# 360    good day
# 361    good day
# 362    good day
# 363    good day
# 364    good day
# Name: Follower Gained, Length: 365, dtype: object

# %%
subs.mean()
# Out:
# Follower Gained    135.643836
# dtype: float64

# %%
# copy

# %%
ronaldo_goals
# Out:
# year
# 2002     5
# 2003     1
# 2004    13
# 2005    15
# 2006    25
# 2007    34
# 2008    35
# 2009    30
# 2010    48
# 2011    60
# 2012    63
# 2013    69
# 2014    61
# 2015    57
# 2016    55
# 2017    53
# 2018    49
# 2019    39
# 2020    44
# 2021    47
# 2022    16
# 2023    54
# 2024    43
# 2025    41
# Name: number_of_goals_scored, dtype: int64

# %%
new = ronaldo_goals.head()

# %%
new
# Out:
# year
# 2002     5
# 2003     1
# 2004    13
# 2005    15
# 2006    25
# Name: number_of_goals_scored, dtype: int64

# %%
new[1] = 1

# %%
new = ronaldo_goals.head().copy()

# %%
new[1] = 100

# %%
new
# Out:
# year
# 2002      5
# 2003      1
# 2004     13
# 2005     15
# 2006     25
# 1       100
# Name: number_of_goals_scored, dtype: int64

# %%
ronaldo_goals
# Out:
# year
# 2002     5
# 2003     1
# 2004    13
# 2005    15
# 2006    25
# 2007    34
# 2008    35
# 2009    30
# 2010    48
# 2011    60
# 2012    63
# 2013    69
# 2014    61
# 2015    57
# 2016    55
# 2017    53
# 2018    49
# 2019    39
# 2020    44
# 2021    47
# 2022    16
# 2023    54
# 2024    43
# 2025    41
# Name: number_of_goals_scored, dtype: int64
